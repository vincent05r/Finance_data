# %%
import os
import pandas as pd
import random
from pathlib import Path
from typing import Union

def split_dataset(
    root_dir: Union[str, Path],
    val_ratio: float = 0.1,
    val_files_ratio: float = 1.0,
    output_dir: Union[str, Path] = "val_split",
    seed: int = 42,
    min_length: int = 512,
):
    """
    Splits a proportion of time series CSV files into validation sets.
    Optionally select only a subset of files to apply the split.

    Args:
        root_dir (str or Path): Root directory containing time series data.
        val_ratio (float): Proportion of each selected file's data to use for validation.
        val_files_ratio (float): Proportion of files to be split into validation.
        output_dir (str or Path): Root directory to save validation files.
        seed (int): Random seed for reproducibility.
    """
    root_dir = Path(root_dir)
    output_dir = Path(output_dir)
    
    # Collect all csv file paths
    all_csv_files = []
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith(".csv"):
                file_path = Path(subdir) / file
                try:
                    df = pd.read_csv(file_path)
                except Exception as e:
                    print(f"❌ Error reading {file_path}: {e}")
                    continue

                if len(df) < min_length:
                    continue
                all_csv_files.append(Path(subdir) / file)


    # Select a subset of files for validation
    random.seed(seed)
    num_val_files = int(len(all_csv_files) * val_files_ratio)
    selected_files = random.sample(all_csv_files, num_val_files)

    for file_path in selected_files:
        print(f"Processing: {file_path}")

        # Read CSV
        df = pd.read_csv(file_path)
        df.rename(columns={"Date": "Datetime"}, inplace=True)


        split_len = max(int(len(df) * val_ratio), min_length)
        if split_len == 0:
            print(f"⚠️ Skipping {file_path}: split length is 0")
            continue


        # Split by proportion
        split_idx = int(len(df) - split_len)
        val_df = df.iloc[split_idx:]

        # Construct output path
        relative_path = file_path.relative_to(root_dir)
        val_file_path = output_dir / relative_path

        # Ensure directory exists
        val_file_path.parent.mkdir(parents=True, exist_ok=True)

        # Save validation file
        val_df.to_csv(val_file_path, index=False)

# %%
data_dir = r'finance_v1_nv\v1_no_volume'
val_ratio_each_f: float = 0.3
val_file_ratio: float = 0.2
output_dir = r'test_v1_nv'
random_seed = 42
min_length = 512



split_dataset(root_dir=data_dir, val_ratio=val_ratio_each_f, val_files_ratio=val_file_ratio, output_dir=output_dir, seed=random_seed, min_length=min_length)
# Out:
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601678.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301207.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\1038.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\MKS.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\601777.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\301165.SZ_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600761.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\SO_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600098.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\ETR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600252.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600163.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600409.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600850.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\IHG.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\WRB_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301358.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688733.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\SLB_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\EBAY_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600986.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\TJX_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2359.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1h\CAD=X_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600720.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\EXR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\MCHP_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2319.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600578.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600696.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\CSCO_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600750.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600361.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\ITW_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600556.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\ATO_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\TSLA_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\HWDN.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600728.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\APTV_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\MO_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603915.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\HWM_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688388.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\WBA_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\0388.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\BXP_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688275.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605376.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600821.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\ADM.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\3988.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688499.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\IMB.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600691.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\IT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2331.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\WAB_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\COO_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600864.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\ELV_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\XEL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600483.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\PHNX.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688048.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\601952.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\MAA_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\LSEG.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600882.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\BSX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\IP_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\VOD.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600882.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\CRWD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603013.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\BKG.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600266.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\LULU_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\UNP_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\RKT.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603877.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600557.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\INTU_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600604.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\TECH_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\SMCI_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AOS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\301367.SZ_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\IHG.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\RKT.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NUE_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\DGE.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\HUBB_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\TRMB_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\CAH_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600874.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688733.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\APA_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\PNW_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600284.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600882.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601326.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600477.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600740.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\EW_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603588.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\MCD_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\KKR_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\DGX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\INCY_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\CCH.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\WST_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1wk\CHF=X_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603027.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\MS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\NXT.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\MAR_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601702.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\0700.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MAA_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600662.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\WBA_1h.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1m\ETH-USD_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\FCIT.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\TRMB_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603489.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\AFL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600955.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\2359.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688739.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\FOX_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600787.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NWS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\JCI_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1d\DOGE-USD_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\CPRT_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MTCH_1m.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1m\HO=F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601801.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\CFG_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\2331.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\AZN.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603105.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\CRDA.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600017.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MCO_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605338.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\LH_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603989.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688018.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\GDDY_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\T_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600997.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\IMB.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\HOLX_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\FE_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600586.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NWSA_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600075.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\COST_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\TPL_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\FIS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MTD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\C_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\ULTA_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603565.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\SPX.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\603100.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603612.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\FTNT_1m.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1m\ZW=F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\XYL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\DCC.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600976.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1h\EURGBP=X_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688033.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603169.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\BEZ.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603979.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600223.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\PEP_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688031.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\CCL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\VOD.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2628.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MAA_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600657.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688202.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\EVRG_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\HSX.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\EXE_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\ALGN_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688185.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600449.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600559.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\JNPR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\TMUS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\FIS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\BLK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CZR_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601882.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600604.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603299.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\V_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\ISRG_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601222.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\ULVR.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688239.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688173.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\MPC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\TEL_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\301200.SZ_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603938.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CAG_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\AHT.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688238.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PPG_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\UNH_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600595.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601200.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\PFE_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1d\NG=F_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600395.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\SGE.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\601126.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\AIG_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MA_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\JCI_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600643.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\UNH_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603129.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600976.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\IFF_1d.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1h\SOL-USD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\OXY_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\IMI.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\WTW_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\1038.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\FDX_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MKC_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600559.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688161.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\1378.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600783.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603128.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\POOL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603306.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\GEHC_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603083.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601101.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\GRMN_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\VICI_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\KEYS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600641.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603057.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\AIZ_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688526.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\605507.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605111.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603995.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\PSH.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\WMT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603396.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\PSN.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600601.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688680.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\DVN_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\EVRG_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\MNST_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\ALW.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600248.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\GOOG_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\ABF.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\KGF.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\SNA_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688133.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\9618.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AIZ_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\META_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688116.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1m\EURAUD=X_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AMP_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600649.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688139.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NDSN_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600623.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\WY_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688232.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\EXC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605168.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\LAND.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\ECL_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\0992.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600648.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\NCLH_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\REG_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0285.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\IFF_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1h\JPY=X_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\3968.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600783.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688333.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603083.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600986.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0291.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\0101.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600550.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\PYPL_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600210.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\HIK.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\WSM_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\BTRW.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601212.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600338.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\1810.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600770.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1m\XRP-USD_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\ADSK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688131.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\BNZL.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PG_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\V_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\HPE_1h.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1m\EURJPY=X_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688235.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600305.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\SPG_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600456.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\DVN_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\WFC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600252.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\IQV_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\605376.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600662.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\3968.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\COF_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600602.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\ANET_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600502.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\ABF.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600773.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\REGN_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600556.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\SMIN.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600861.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603301.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\CAT_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301205.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603566.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\VRSK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\BXP_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\STAN.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600711.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601068.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\LDOS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600572.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\EG_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\601515.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600006.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AZO_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\GOOGL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0992.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\AAL.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\601678.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301090.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688322.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\TGT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\MELI_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2688.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605369.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\3968.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\MAR_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\AOS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\TSCO_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\ROST_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600057.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603071.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\AZN.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603477.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\ITRK.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600556.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601101.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\LYV_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\ADSK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MMC_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\BAX_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603093.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\MDT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688167.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\IMB.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600773.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MKTX_1h.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1h\BTC-USD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\DVN_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NOW_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688596.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\CMI_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\J_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688007.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\PCAR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\GILD_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603896.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\9901.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\ACN_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\AEP_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\APD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\GOOGL_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\VTR_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\1093.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\ZTS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\605365.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688262.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\EMN_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\INCY_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603105.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0002.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\AEE_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\TGT_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1d\BTC-USD_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0823.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\1876.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600507.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\IRM_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\APP_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CMS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PKG_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600641.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\BAC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\EXPE_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\601811.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\301293.SZ_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\0836.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\CMI_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\BIIB_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600400.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\PHNX.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\AXON_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688789.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600211.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301177.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600861.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688127.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\XOM_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\CNC_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688372.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\LW_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\PSX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\TRV_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\INF.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600216.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1d\NZDJPY=X_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600966.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\GE_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600861.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603208.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\DE_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CL_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601126.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\WTB.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603583.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\ACN_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688268.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CME_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\KEY_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\ODFL_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PNC_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\WFC_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\HBAN_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\SLB_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600710.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\FOX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\TROW_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\STJ.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\SGE.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2015.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\EMR_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\LOW_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\ANTO.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0968.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\NVR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688333.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\1099.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\MRO.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0101.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\CEG_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\TTWO_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\PARA_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688575.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600366.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\GAW.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\LII_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600475.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600645.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603638.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\COO_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\AMP_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\REGN_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\PSA_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CPAY_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\CTRA_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603477.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600361.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\EIX_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\NUE_1d.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1m\KC=F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\JBL_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\GWW_1m.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1d\USDNOK=X_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\MNST_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\2388.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\OKE_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\DUK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NOC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\STT_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600993.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MSI_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600876.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0388.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MHK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600116.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\NOW_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\CMCSA_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\WTW_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\DAY_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\605507.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600006.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\RF_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600012.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\301200.SZ_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\HWM_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688518.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\BLK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603730.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\WTB.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\KLAC_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600577.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\WRB_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\INTU_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\DXCM_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\2382.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\ESS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\DPLM.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688676.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\ECL_1m.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1m\HG=F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601515.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\HON_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\603005.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605123.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600612.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600211.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688800.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1m\YM=F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600456.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\AAL.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\605020.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\FDS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603025.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600797.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\MRO.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\DTE_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\601369.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600916.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\CDNS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301267.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\CRWD_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\GL_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\STT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688696.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688268.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\HSBA.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600728.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0012.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600641.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\BKR_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\LII_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\EMR_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605222.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\MSTR_1m.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1wk\GBPUSD=X_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\NTAP_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600882.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\LLY_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\CAT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AVB_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600478.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MDT_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603229.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\EQIX_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\WEIR.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NKE_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\LDOS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CMI_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MET_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\SGE.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\ARM_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\NXT.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600072.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\3690.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\TYL_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\IMI.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\CPRT_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600100.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\DASH_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603733.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MPC_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\600595.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\VRSK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\SGRO.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\MDB_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\6862.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\1299.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\forex_datasets\1m\GBPUSD=X_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\CPT_1wk.csv
# ...
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600612.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1m\AVAX-USD_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\APH_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\DVN_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\0006.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600295.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\GSK.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\2331.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\0322.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\WELL_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688046.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\LAND.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688660.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603033.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\SCHW_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1wk\603108.SS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600295.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\LAND.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\301316.SZ_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603208.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\601069.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\2628.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\NOW_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603881.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\DLR_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0857.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\VZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0288.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\TRGP_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\O_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\PPG_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\MTB_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688559.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\KMI_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\BAB.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\301268.SZ_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600312.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1m\ZN=F_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\SVT.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603170.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\EFX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\DLTR_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603719.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600305.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\D_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\COST_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\ADI_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\ADI_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600850.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600775.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\ORLY_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\ROK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\2359.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\UAL_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\UHS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600478.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\WSM_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600158.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\INTC_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\EDV.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\CCEP_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603100.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\WST_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\CHRW_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\crypto_datasets\crypto10\1d\XRP-USD_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\PRU_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\BRO_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\CHD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601886.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688048.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\DHI_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\BX_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\SYF_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PH_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\601333.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\TSN_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688139.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\2319.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\LUV_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600110.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\AUTO.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600675.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\BKNG_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\USB_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1d\CL=F_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\WEC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\AON_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600391.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\601963.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\BK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\603187.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600508.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\SW_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\0066.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\AME_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0762.HK_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\CPT_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\KKR_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\ESS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\IMB.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AEE_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\VRSN_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600072.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\LOW_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688192.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\ALB_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\688586.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605589.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\COP_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\LRCX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\AIG_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1wk\PRU.L_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\0386.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\2382.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\NOC_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600273.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\SPG_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\NSC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\LMT_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\AAPL_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\WBD_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\RF_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\HLT_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\AMGN_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\688110.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\ADM.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\LGEN.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\BK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600740.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\PEP_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\KEYS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\MMC_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600449.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\RMD_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600490.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\UNH_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\TTWO_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600667.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\OKE_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600643.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\GPC_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AFL_1m.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1d\YM=F_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600058.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\BALL_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600550.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688206.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\DTE_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1m\GOOGL_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\SYY_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688556.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\MNST_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\LVS_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1d\MSTR_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\MRNA_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\PHM_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600452.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\605090.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\PCT.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\2015.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1h\600259.SS_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\LUV_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PSX_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\3988.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\600835.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1h\CSCO_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\603025.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\0688.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\APH_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\GEN_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\JCI_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600123.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\KGF.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\CAH_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603609.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\601860.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\603169.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688389.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1h\CPG.L_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\STLD_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\301381.SZ_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\HWDN.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\BDX_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\HSX.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\ARE_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\LAND.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\CNP_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1h\2269.HK_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1wk\SWK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1m\600657.SS_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\csi500\1d\688167.SS_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\PGR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\nasdaq100\1wk\ADP_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\3690.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1h\FSLR_1h.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1m\ANTO.L_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\AES_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1wk\0101.HK_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\MA_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1m\KVUE_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\ftse100\1d\STAN.L_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\sp500\1d\KEY_1d.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\1099.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1m\1024.HK_1m.csv
# Processing: finance_v1_nv\v1_no_volume\futures_datasets\1wk\HG=F_1wk.csv
# Processing: finance_v1_nv\v1_no_volume\stock_datasets\hsi\1d\0960.HK_1d.csv

# %%
print("done")
# Out:
# done

# %%
#restructuring dataset dir
import os
import shutil
from pathlib import Path

def restructure_dataset(parent_dir: str, result_dir: str):
    parent_path = Path(parent_dir).resolve()
    result_path = Path(result_dir).resolve()

    assert parent_path.exists(), f"Directory {parent_dir} does not exist."
    result_path.mkdir(parents=True, exist_ok=True)

    # Iterate through each subdirectory
    for sub in sorted(parent_path.iterdir()):
        if sub.is_dir():
            new_dir_name = f"{parent_path.name}_{sub.name}"
            new_dir_path = result_path / new_dir_name
            new_dir_path.mkdir(parents=True, exist_ok=True)

            # Copy all files/subfolders from original subdir to new_dir_path
            for item in sub.iterdir():
                target = new_dir_path / item.name
                if item.is_dir():
                    shutil.copytree(item, target, dirs_exist_ok=True)
                else:
                    shutil.copy2(item, target)

            print(f"Copied contents from {sub} → {new_dir_path}")

# %%
# Replace this with your actual path
target_dir = r'test_v1_nv\futures_datasets'
result_dir = r'test_v1_nv_flat'
restructure_dataset(target_dir, result_dir=result_dir)
# Out:
# Copied contents from F:\program repo\Finance_data\test_v1_nv\futures_datasets\1d → F:\program repo\Finance_data\test_v1_nv_flat\futures_datasets_1d
# Copied contents from F:\program repo\Finance_data\test_v1_nv\futures_datasets\1h → F:\program repo\Finance_data\test_v1_nv_flat\futures_datasets_1h
# Copied contents from F:\program repo\Finance_data\test_v1_nv\futures_datasets\1m → F:\program repo\Finance_data\test_v1_nv_flat\futures_datasets_1m
# Copied contents from F:\program repo\Finance_data\test_v1_nv\futures_datasets\1wk → F:\program repo\Finance_data\test_v1_nv_flat\futures_datasets_1wk

# %%
#for market stock dir flat

# %%
import shutil
from pathlib import Path

def regroup_by_frequency_copy(root_dir: str, result_dir: str):
    root_path = Path(root_dir).resolve()
    result_path = Path(result_dir).resolve()

    assert root_path.exists(), f"Directory {root_dir} does not exist."
    result_path.mkdir(parents=True, exist_ok=True)

    for market_dir in sorted(root_path.iterdir()):
        if not market_dir.is_dir():
            continue

        for freq_dir in sorted(market_dir.iterdir()):
            if not freq_dir.is_dir():
                continue

            freq = freq_dir.name
            market = market_dir.name

            # Define target: result_dir/stock_datasets_<freq>/<market>/
            target_base = result_path / f"{root_path.name}_{freq}"
            target_market_dir = target_base / market
            target_market_dir.mkdir(parents=True, exist_ok=True)

            # Copy all files/subfolders recursively
            for item in freq_dir.iterdir():
                target_item = target_market_dir / item.name
                if item.is_dir():
                    shutil.copytree(item, target_item, dirs_exist_ok=True)
                else:
                    shutil.copy2(item, target_item)

            print(f"Copied {freq_dir} → {target_market_dir}")

# %%
target_dir = r'test_v1_nv\stock_datasets'
result_dir = r'test_v1_nv_flat'
regroup_by_frequency_copy(root_dir=target_dir, result_dir=result_dir)
# Out:
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\csi500\1d → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1d\csi500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\csi500\1h → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1h\csi500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\csi500\1m → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1m\csi500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\csi500\1wk → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1wk\csi500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\ftse100\1d → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1d\ftse100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\ftse100\1h → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1h\ftse100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\ftse100\1m → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1m\ftse100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\ftse100\1wk → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1wk\ftse100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\hsi\1d → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1d\hsi
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\hsi\1h → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1h\hsi
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\hsi\1m → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1m\hsi
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\hsi\1wk → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1wk\hsi
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\nasdaq100\1d → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1d\nasdaq100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\nasdaq100\1h → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1h\nasdaq100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\nasdaq100\1m → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1m\nasdaq100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\nasdaq100\1wk → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1wk\nasdaq100
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\sp500\1d → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1d\sp500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\sp500\1h → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1h\sp500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\sp500\1m → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1m\sp500
# Copied F:\program repo\Finance_data\test_v1_nv\stock_datasets\sp500\1wk → F:\program repo\Finance_data\test_v1_nv_flat\stock_datasets_1wk\sp500

# %%
print("done")
# Out:
# done
