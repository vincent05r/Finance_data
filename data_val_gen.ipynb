# %%
import os
import pandas as pd
import random
from pathlib import Path
from typing import Union

def split_dataset(
    root_dir: Union[str, Path],
    val_ratio: float = 0.1,
    val_files_ratio: float = 1.0,
    output_dir: Union[str, Path] = "val_split",
    seed: int = 42,
):
    """
    Splits a proportion of time series CSV files into validation sets.
    Optionally select only a subset of files to apply the split.

    Args:
        root_dir (str or Path): Root directory containing time series data.
        val_ratio (float): Proportion of each selected file's data to use for validation.
        val_files_ratio (float): Proportion of files to be split into validation.
        output_dir (str or Path): Root directory to save validation files.
        seed (int): Random seed for reproducibility.
    """
    root_dir = Path(root_dir)
    output_dir = Path(output_dir)
    
    # Collect all csv file paths
    all_csv_files = []
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith(".csv"):
                all_csv_files.append(Path(subdir) / file)

    # Select a subset of files for validation
    random.seed(seed)
    num_val_files = int(len(all_csv_files) * val_files_ratio)
    selected_files = random.sample(all_csv_files, num_val_files)

    for file_path in selected_files:
        print(f"Processing: {file_path}")

        # Read CSV
        df = pd.read_csv(file_path)

        # Sort by timestamp if necessary
        if 'timestamp' in df.columns:
            df = df.sort_values(by='timestamp')

        # Split by proportion
        split_idx = int(len(df) * (1 - val_ratio))
        val_df = df.iloc[split_idx:]

        # Construct output path
        relative_path = file_path.relative_to(root_dir)
        val_file_path = output_dir / relative_path

        # Ensure directory exists
        val_file_path.parent.mkdir(parents=True, exist_ok=True)

        # Save validation file
        val_df.to_csv(val_file_path, index=False)

# %%
data_dir = r'v1_no_volume'
val_ratio_each_f: float = 0.3
val_file_ratio: float = 0.2
output_dir = r'val_v1_nv'
random_seed = 42



split_dataset(root_dir=data_dir, val_ratio=val_ratio_each_f, val_files_ratio=val_file_ratio, output_dir=output_dir, seed=random_seed)
# Out:
# Processing: v1_no_volume\stock_datasets\csi500\1h\601208.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\301095.SZ_1d.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\BARC.L_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603730.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600751.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\688639.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600657.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\VZ_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\301291.SZ_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\SW_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\JNPR_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600158.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600058.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600312.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600587.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\601718.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\CF_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\301219.SZ_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\DOV_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688556.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\VST_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\HWM_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600641.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\AMP_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\SPGI_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\HLMA.L_1h.csv
# Processing: v1_no_volume\forex_datasets\1d\JPY=X_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600639.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\KKR_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\0836.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\GSK.L_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600480.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600452.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\9901.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600648.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600259.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\MSFT_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600452.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1d\VRTX_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\2015.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1d\BKG.L_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600643.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\DIS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\RCL_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\603678.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\KLAC_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688289.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\AVY_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\RMV.L_1m.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1h\AZN_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\LYV_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688161.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\603936.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600740.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600986.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\HSX.L_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688333.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\601801.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600612.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\MSTR_1m.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\HIK.L_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\CAG_1h.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1h\GFS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\
1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\PCG_1wk.csv
# Processing: v1_no_volume\futures_datasets\1h\ZT=F_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\LEN_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\NXPI_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\MDT_1h.csv
# Processing: v1_no_volume\forex_datasets\1d\EURJPY=X_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1d\DXCM_1d.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\DPLM.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1wk\IDXX_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\HST_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\SNA_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\WEC_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600643.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\SRE_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600610.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1d\SVT.L_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\RSG_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600006.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1wk\FANG_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\6862.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\CINF_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\GPC_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\603938.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\301246.SZ_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1wk\PYPL_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\TGT_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\ESS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\301267.SZ_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688639.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\MTB_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\688268.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\ELV_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\603565.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688578.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\0005.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600273.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\CF_1h.csv
# Processing: v1_no_volume\stock_datasets\hsi\1h\9999.HK_1h.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\0005.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\HSBA.L_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\JCI_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688127.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688409.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\IBM_1h.csv
# Processing: v1_no_volume\futures_datasets\1h\ZN=F_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\601069.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1d\CDNS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600780.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\603881.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600550.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600116.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688586.SS_1m.csv
# Processing: v1_no_volume\futures_datasets\1m\GC=F_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600335.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603171.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\603871.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\KMI_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\601858.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\EQR_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600562.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688318.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1h\PAYX_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\601011.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600783.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\hsi\1d\0992.HK_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\MHK_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\301177.SZ_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1d\1109.HK_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\CRWD_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\ACN_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688499.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688161.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\TKO_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603583.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600641.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\KGF.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\FE_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600575.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1d\AAPL_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\OTIS_1m.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1h\TSLA_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\603896.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\0968.HK_1wk.csv
# Processing: v1_no_volume\forex_datasets\1wk\CHF=X_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\TEL_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600777.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\PNR_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1h\CDNS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\DOC_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600363.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\RMD_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\603098.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\IP_1m.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1d\NXT.L_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\SMCI_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\PHM_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\FICO_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\ROK_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\TPR_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1d\IMI.L_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1h\1177.HK_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603876.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\301217.SZ_1h.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\IHG.L_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\AVY_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603666.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\HES_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\9633.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\301376.SZ_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1h\2688.HK_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\603566.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\SNA_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600305.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1d\MDLZ_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688389.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\0857.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\KGF.L_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\V_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\CRDA.L_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\CFG_1wk.csv
# Processing: v1_no_volume\forex_datasets\1m\CHF=X_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\F_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688110.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603396.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\CBOE_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603301.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\L_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\TKO_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\AJG_1h.csv
# Processing: v1_no_volume\futures_datasets\1h\BZ=F_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600273.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\SPX.L_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\600685.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603609.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\VOD.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\NI_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1h\PDD_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\BG_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\NI_1m.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\1997.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d
1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\AON_1wk.csv
# Processing: v1_no_volume\forex_datasets\1wk\GBPUSD=X_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\AXP_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\DE_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600284.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\601619.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\EG_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\603063.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600420.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\AES_1m.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\NWG.L_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\DAY_1m.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1d\VOD.L_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\GDDY_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\PARA_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\JCI_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603638.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\CPAY_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\APD_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\301316.SZ_1m.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\WDAY_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688091.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\CVS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\688321.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\603979.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\FRT_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\0700.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\CRL_1m.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1d\HLMA.L_1d.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1h\SHEL.L_1h.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\DGE.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\REG_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\MPWR_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\TAP_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600169.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\ZBH_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\SPGI_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\PNW_1h.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\2628.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\1177.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\UDR_1m.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\GILD_1m.csv
# Processing: v1_no_volume\stock_datasets\hsi\1h\1093.HK_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\688007.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603187.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\IEX_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\601886.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\EG_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600648.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1h\0175.HK_1h.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\PDD_1m.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1wk\AZN_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600330.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\WDC_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600395.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\BAX_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\STZ_1wk.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\1093.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600596.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\TMO_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600575.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\LNT_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\CPT_1h.csv
# Processing: v1_no_volume\futures_datasets\1d\GE=F_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\301291.SZ_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\DVA_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600446.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688110.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\HSIC_1h.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\0241.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\AJG_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688356.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1m\0267.HK_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\PFE_1m.csv
# Processing: v1_no_volume\stock_datasets\hsi\1d\9999.HK_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\SPGI_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\TFC_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600335.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\603876.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\601975.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\DCC.L_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1h\600158.SS_1h.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\PPG_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\VST_1d.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\GAW.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\600750.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1h\2331.HK_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\601860.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\SBRY.L_1m.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1d\TTD_1d.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\CHTR_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\NVR_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600006.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603693.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\EQR_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\603348.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\601330.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\603043.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688298.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603328.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\ABBV_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\OMC_1wk.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\301219.SZ_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\601677.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\ECL_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688198.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\DLR_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688266.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\FI_1h.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\DPLM.L_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1m\WMT_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1m\600587.SS_1m.csv
# Processing: v1_no_volume\stock_datasets\csi500\1d\688066.SS_1d.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\T_1d.csv
# Processing: v1_no_volume\stock_datasets\hsi\1wk\3690.HK_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\ROK_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\EZJ.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1d\LKQ_1d.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\688023.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\CPB_1h.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\LMP.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1wk\AEP_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1h\PGR_1h.csv
# Processing: v1_no_volume\stock_datasets\csi500\1wk\603105.SS_1wk.csv
# Processing: v1_no_volume\stock_datasets\nasdaq100\1m\PEP_1m.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\IFF_1wk.csv
# Processing: v1_no_volume\stock_datasets\sp500\1wk\KMB_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1wk\AAL.L_1wk.csv
# Processing: v1_no_volume\stock_datasets\ftse100\1m\VOD.L_1m.csv

# %%
print("done")
# Out:
# done
