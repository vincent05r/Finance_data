# %%
import os
import pandas as pd

# %%
def drop_columns_in_csvs(root_dir, columns_to_drop):
    """
    Recursively traverses all subdirectories of root_dir, processes each CSV file found by
    dropping the specified columns in-place.

    Parameters:
    - root_dir: str, path to the root directory.
    - columns_to_drop: list of str, column names to drop.
    """
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.csv'):
                file_path = os.path.join(dirpath, filename)
                try:
                    # Load CSV
                    df = pd.read_csv(file_path)

                    # Drop columns that exist in the DataFrame
                    cols_in_df = [col for col in columns_to_drop if col in df.columns]
                    if cols_in_df:
                        df.drop(columns=cols_in_df, inplace=True)
                        # Save back to the same file
                        df.to_csv(file_path, index=False)
                        print(f"Updated: {file_path} - Dropped columns: {cols_in_df}")
                    else:
                        print(f"Skipped: {file_path} - No matching columns to drop.")

                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

# %%
# Example usage
directory_path = r"v1_no_volume"  # Replace this with the actual path
columns_to_remove = ["Volume"]   # Replace with your target column names
drop_columns_in_csvs(directory_path, columns_to_remove)

# %%
print("done")

# %%
print("done")

# %%
#rn for freq map
def rename_csv_files_with_parent(directory):
    """
    Traverse all subdirectories of `directory`, and rename .csv files by appending
    their immediate parent directory name (before the extension).
    Example: "ADA-USD.csv" in "1d" folder becomes "ADA-USD_1d.csv"
    """
    for root, _, files in os.walk(directory):
        parent_folder = os.path.basename(root)
        for filename in files:
            if filename.endswith('.csv'):
                old_path = os.path.join(root, filename)
                name, ext = os.path.splitext(filename)
                new_name = f"{name}_{parent_folder}{ext}"
                new_path = os.path.join(root, new_name)

                # Avoid renaming if the new name already exists or name is unchanged
                if old_path != new_path:
                    print(f"Renaming: {old_path} -> {new_path}")
                    os.rename(old_path, new_path)

# %%
rename_csv_files_with_parent(r'./v1_no_volume')
# Out:
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\ADA-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\ADA-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\AVAX-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\AVAX-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\BNB-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\BNB-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\BTC-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\BTC-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\DOGE-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\DOGE-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\DOT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\DOT-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\ETH-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\ETH-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\SOL-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\SOL-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\USDT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\USDT-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1d\XRP-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1d\XRP-USD_1d.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\ADA-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\ADA-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\AVAX-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\AVAX-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\BNB-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\BNB-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\BTC-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\BTC-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\DOGE-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\DOGE-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\DOT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\DOT-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\ETH-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\ETH-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\SOL-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\SOL-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\USDT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\USDT-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1h\XRP-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1h\XRP-USD_1h.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\ADA-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\ADA-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\AVAX-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\AVAX-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\BNB-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\BNB-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\BTC-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\BTC-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\DOGE-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\DOGE-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\DOT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\DOT-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\ETH-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\ETH-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\SOL-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\SOL-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\USDT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\USDT-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1m\XRP-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1m\XRP-USD_1m.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\ADA-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\ADA-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\AVAX-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\AVAX-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\BNB-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\BNB-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\BTC-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\BTC-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\DOGE-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\DOGE-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\DOT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\DOT-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\ETH-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\ETH-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\SOL-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\SOL-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\USDT-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\USDT-USD_1wk.csv
# Renaming: ./v1_no_volume\crypto_datasets\crypto10\1wk\XRP-USD.csv -> ./v1_no_volume\crypto_datasets\crypto10\1wk\XRP-USD_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\AUDJPY=X.csv -> ./v1_no_volume\forex_datasets\1d\AUDJPY=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\AUDUSD=X.csv -> ./v1_no_volume\forex_datasets\1d\AUDUSD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\CAD=X.csv -> ./v1_no_volume\forex_datasets\1d\CAD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\CHF=X.csv -> ./v1_no_volume\forex_datasets\1d\CHF=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\CHFJPY=X.csv -> ./v1_no_volume\forex_datasets\1d\CHFJPY=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\EURAUD=X.csv -> ./v1_no_volume\forex_datasets\1d\EURAUD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\EURCHF=X.csv -> ./v1_no_volume\forex_datasets\1d\EURCHF=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\EURGBP=X.csv -> ./v1_no_volume\forex_datasets\1d\EURGBP=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\EURJPY=X.csv -> ./v1_no_volume\forex_datasets\1d\EURJPY=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\EURUSD=X.csv -> ./v1_no_volume\forex_datasets\1d\EURUSD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\GBPCHF=X.csv -> ./v1_no_volume\forex_datasets\1d\GBPCHF=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\GBPJPY=X.csv -> ./v1_no_volume\forex_datasets\1d\GBPJPY=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\GBPUSD=X.csv -> ./v1_no_volume\forex_datasets\1d\GBPUSD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\JPY=X.csv -> ./v1_no_volume\forex_datasets\1d\JPY=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\NZDJPY=X.csv -> ./v1_no_volume\forex_datasets\1d\NZDJPY=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\NZDUSD=X.csv -> ./v1_no_volume\forex_datasets\1d\NZDUSD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\USDMXN=X.csv -> ./v1_no_volume\forex_datasets\1d\USDMXN=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\USDNOK=X.csv -> ./v1_no_volume\forex_datasets\1d\USDNOK=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\USDSEK=X.csv -> ./v1_no_volume\forex_datasets\1d\USDSEK=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1d\USDSGD=X.csv -> ./v1_no_volume\forex_datasets\1d\USDSGD=X_1d.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\AUDJPY=X.csv -> ./v1_no_volume\forex_datasets\1h\AUDJPY=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\AUDUSD=X.csv -> ./v1_no_volume\forex_datasets\1h\AUDUSD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\CAD=X.csv -> ./v1_no_volume\forex_datasets\1h\CAD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\CHF=X.csv -> ./v1_no_volume\forex_datasets\1h\CHF=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\CHFJPY=X.csv -> ./v1_no_volume\forex_datasets\1h\CHFJPY=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\EURAUD=X.csv -> ./v1_no_volume\forex_datasets\1h\EURAUD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\EURCHF=X.csv -> ./v1_no_volume\forex_datasets\1h\EURCHF=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\EURGBP=X.csv -> ./v1_no_volume\forex_datasets\1h\EURGBP=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\EURJPY=X.csv -> ./v1_no_volume\forex_datasets\1h\EURJPY=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\EURUSD=X.csv -> ./v1_no_volume\forex_datasets\1h\EURUSD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\GBPCHF=X.csv -> ./v1_no_volume\forex_datasets\1h\GBPCHF=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\GBPJPY=X.csv -> ./v1_no_volume\forex_datasets\1h\GBPJPY=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\GBPUSD=X.csv -> ./v1_no_volume\forex_datasets\1h\GBPUSD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\JPY=X.csv -> ./v1_no_volume\forex_datasets\1h\JPY=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\NZDJPY=X.csv -> ./v1_no_volume\forex_datasets\1h\NZDJPY=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\NZDUSD=X.csv -> ./v1_no_volume\forex_datasets\1h\NZDUSD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\USDMXN=X.csv -> ./v1_no_volume\forex_datasets\1h\USDMXN=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\USDNOK=X.csv -> ./v1_no_volume\forex_datasets\1h\USDNOK=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\USDSEK=X.csv -> ./v1_no_volume\forex_datasets\1h\USDSEK=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1h\USDSGD=X.csv -> ./v1_no_volume\forex_datasets\1h\USDSGD=X_1h.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\AUDJPY=X.csv -> ./v1_no_volume\forex_datasets\1m\AUDJPY=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\AUDUSD=X.csv -> ./v1_no_volume\forex_datasets\1m\AUDUSD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\CAD=X.csv -> ./v1_no_volume\forex_datasets\1m\CAD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\CHF=X.csv -> ./v1_no_volume\forex_datasets\1m\CHF=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\CHFJPY=X.csv -> ./v1_no_volume\forex_datasets\1m\CHFJPY=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\EURAUD=X.csv -> ./v1_no_volume\forex_datasets\1m\EURAUD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\EURCHF=X.csv -> ./v1_no_volume\forex_datasets\1m\EURCHF=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\EURGBP=X.csv -> ./v1_no_volume\forex_datasets\1m\EURGBP=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\EURJPY=X.csv -> ./v1_no_volume\forex_datasets\1m\EURJPY=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\EURUSD=X.csv -> ./v1_no_volume\forex_datasets\1m\EURUSD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\GBPCHF=X.csv -> ./v1_no_volume\forex_datasets\1m\GBPCHF=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\GBPJPY=X.csv -> ./v1_no_volume\forex_datasets\1m\GBPJPY=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\GBPUSD=X.csv -> ./v1_no_volume\forex_datasets\1m\GBPUSD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\JPY=X.csv -> ./v1_no_volume\forex_datasets\1m\JPY=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\NZDJPY=X.csv -> ./v1_no_volume\forex_datasets\1m\NZDJPY=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\NZDUSD=X.csv -> ./v1_no_volume\forex_datasets\1m\NZDUSD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\USDMXN=X.csv -> ./v1_no_volume\forex_datasets\1m\USDMXN=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\USDNOK=X.csv -> ./v1_no_volume\forex_datasets\1m\USDNOK=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\USDSEK=X.csv -> ./v1_no_volume\forex_datasets\1m\USDSEK=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1m\USDSGD=X.csv -> ./v1_no_volume\forex_datasets\1m\USDSGD=X_1m.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\AUDJPY=X.csv -> ./v1_no_volume\forex_datasets\1wk\AUDJPY=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\AUDUSD=X.csv -> ./v1_no_volume\forex_datasets\1wk\AUDUSD=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\CAD=X.csv -> ./v1_no_volume\forex_datasets\1wk\CAD=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\CHF=X.csv -> ./v1_no_volume\forex_datasets\1wk\CHF=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\CHFJPY=X.csv -> ./v1_no_volume\forex_datasets\1wk\CHFJPY=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\EURAUD=X.csv -> ./v1_no_volume\forex_datasets\1wk\EURAUD=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\EURCHF=X.csv -> ./v1_no_volume\forex_datasets\1wk\EURCHF=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\EURGBP=X.csv -> ./v1_no_volume\forex_datasets\1wk\EURGBP=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\EURJPY=X.csv -> ./v1_no_volume\forex_datasets\1wk\EURJPY=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\EURUSD=X.csv -> ./v1_no_volume\forex_datasets\1wk\EURUSD=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\GBPCHF=X.csv -> ./v1_no_volume\forex_datasets\1wk\GBPCHF=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\GBPJPY=X.csv -> ./v1_no_volume\forex_datasets\1wk\GBPJPY=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\GBPUSD=X.csv -> ./v1_no_volume\forex_datasets\1wk\GBPUSD=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\JPY=X.csv -> ./v1_no_volume\forex_datasets\1wk\JPY=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\NZDJPY=X.csv -> ./v1_no_volume\forex_datasets\1wk\NZDJPY=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\NZDUSD=X.csv -> ./v1_no_volume\forex_datasets\1wk\NZDUSD=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\USDMXN=X.csv -> ./v1_no_volume\forex_datasets\1wk\USDMXN=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\USDNOK=X.csv -> ./v1_no_volume\forex_datasets\1wk\USDNOK=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\USDSEK=X.csv -> ./v1_no_volume\forex_datasets\1wk\USDSEK=X_1wk.csv
# Renaming: ./v1_no_volume\forex_datasets\1wk\USDSGD=X.csv -> ./v1_no_volume\forex_datasets\1wk\USDSGD=X_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\BZ=F.csv -> ./v1_no_volume\futures_datasets\1d\BZ=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\CL=F.csv -> ./v1_no_volume\futures_datasets\1d\CL=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\CT=F.csv -> ./v1_no_volume\futures_datasets\1d\CT=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ES=F.csv -> ./v1_no_volume\futures_datasets\1d\ES=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\GC=F.csv -> ./v1_no_volume\futures_datasets\1d\GC=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\GE=F.csv -> ./v1_no_volume\futures_datasets\1d\GE=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\HG=F.csv -> ./v1_no_volume\futures_datasets\1d\HG=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\HO=F.csv -> ./v1_no_volume\futures_datasets\1d\HO=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\KC=F.csv -> ./v1_no_volume\futures_datasets\1d\KC=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\NG=F.csv -> ./v1_no_volume\futures_datasets\1d\NG=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\NQ=F.csv -> ./v1_no_volume\futures_datasets\1d\NQ=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\PL=F.csv -> ./v1_no_volume\futures_datasets\1d\PL=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\RTY=F.csv -> ./v1_no_volume\futures_datasets\1d\RTY=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\SI=F.csv -> ./v1_no_volume\futures_datasets\1d\SI=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\YM=F.csv -> ./v1_no_volume\futures_datasets\1d\YM=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ZC=F.csv -> ./v1_no_volume\futures_datasets\1d\ZC=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ZF=F.csv -> ./v1_no_volume\futures_datasets\1d\ZF=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ZN=F.csv -> ./v1_no_volume\futures_datasets\1d\ZN=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ZS=F.csv -> ./v1_no_volume\futures_datasets\1d\ZS=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ZT=F.csv -> ./v1_no_volume\futures_datasets\1d\ZT=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1d\ZW=F.csv -> ./v1_no_volume\futures_datasets\1d\ZW=F_1d.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\BZ=F.csv -> ./v1_no_volume\futures_datasets\1h\BZ=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\CL=F.csv -> ./v1_no_volume\futures_datasets\1h\CL=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\CT=F.csv -> ./v1_no_volume\futures_datasets\1h\CT=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ES=F.csv -> ./v1_no_volume\futures_datasets\1h\ES=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\GC=F.csv -> ./v1_no_volume\futures_datasets\1h\GC=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\GE=F.csv -> ./v1_no_volume\futures_datasets\1h\GE=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\HG=F.csv -> ./v1_no_volume\futures_datasets\1h\HG=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\HO=F.csv -> ./v1_no_volume\futures_datasets\1h\HO=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\KC=F.csv -> ./v1_no_volume\futures_datasets\1h\KC=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\NG=F.csv -> ./v1_no_volume\futures_datasets\1h\NG=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\NQ=F.csv -> ./v1_no_volume\futures_datasets\1h\NQ=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\PL=F.csv -> ./v1_no_volume\futures_datasets\1h\PL=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\RTY=F.csv -> ./v1_no_volume\futures_datasets\1h\RTY=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\SI=F.csv -> ./v1_no_volume\futures_datasets\1h\SI=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\YM=F.csv -> ./v1_no_volume\futures_datasets\1h\YM=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ZC=F.csv -> ./v1_no_volume\futures_datasets\1h\ZC=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ZF=F.csv -> ./v1_no_volume\futures_datasets\1h\ZF=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ZN=F.csv -> ./v1_no_volume\futures_datasets\1h\ZN=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ZS=F.csv -> ./v1_no_volume\futures_datasets\1h\ZS=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ZT=F.csv -> ./v1_no_volume\futures_datasets\1h\ZT=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1h\ZW=F.csv -> ./v1_no_volume\futures_datasets\1h\ZW=F_1h.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\BZ=F.csv -> ./v1_no_volume\futures_datasets\1m\BZ=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\CL=F.csv -> ./v1_no_volume\futures_datasets\1m\CL=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\CT=F.csv -> ./v1_no_volume\futures_datasets\1m\CT=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ES=F.csv -> ./v1_no_volume\futures_datasets\1m\ES=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\GC=F.csv -> ./v1_no_volume\futures_datasets\1m\GC=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\HG=F.csv -> ./v1_no_volume\futures_datasets\1m\HG=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\HO=F.csv -> ./v1_no_volume\futures_datasets\1m\HO=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\KC=F.csv -> ./v1_no_volume\futures_datasets\1m\KC=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\NG=F.csv -> ./v1_no_volume\futures_datasets\1m\NG=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\NQ=F.csv -> ./v1_no_volume\futures_datasets\1m\NQ=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\PL=F.csv -> ./v1_no_volume\futures_datasets\1m\PL=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\RTY=F.csv -> ./v1_no_volume\futures_datasets\1m\RTY=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\SI=F.csv -> ./v1_no_volume\futures_datasets\1m\SI=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\YM=F.csv -> ./v1_no_volume\futures_datasets\1m\YM=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ZC=F.csv -> ./v1_no_volume\futures_datasets\1m\ZC=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ZF=F.csv -> ./v1_no_volume\futures_datasets\1m\ZF=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ZN=F.csv -> ./v1_no_volume\futures_datasets\1m\ZN=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ZS=F.csv -> ./v1_no_volume\futures_datasets\1m\ZS=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ZT=F.csv -> ./v1_no_volume\futures_datasets\1m\ZT=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1m\ZW=F.csv -> ./v1_no_volume\futures_datasets\1m\ZW=F_1m.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\BZ=F.csv -> ./v1_no_volume\futures_datasets\1wk\BZ=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\CL=F.csv -> ./v1_no_volume\futures_datasets\1wk\CL=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\CT=F.csv -> ./v1_no_volume\futures_datasets\1wk\CT=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ES=F.csv -> ./v1_no_volume\futures_datasets\1wk\ES=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\GC=F.csv -> ./v1_no_volume\futures_datasets\1wk\GC=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\GE=F.csv -> ./v1_no_volume\futures_datasets\1wk\GE=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\HG=F.csv -> ./v1_no_volume\futures_datasets\1wk\HG=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\HO=F.csv -> ./v1_no_volume\futures_datasets\1wk\HO=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\KC=F.csv -> ./v1_no_volume\futures_datasets\1wk\KC=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\NG=F.csv -> ./v1_no_volume\futures_datasets\1wk\NG=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\NQ=F.csv -> ./v1_no_volume\futures_datasets\1wk\NQ=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\PL=F.csv -> ./v1_no_volume\futures_datasets\1wk\PL=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\RTY=F.csv -> ./v1_no_volume\futures_datasets\1wk\RTY=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\SI=F.csv -> ./v1_no_volume\futures_datasets\1wk\SI=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\YM=F.csv -> ./v1_no_volume\futures_datasets\1wk\YM=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ZC=F.csv -> ./v1_no_volume\futures_datasets\1wk\ZC=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ZF=F.csv -> ./v1_no_volume\futures_datasets\1wk\ZF=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ZN=F.csv -> ./v1_no_volume\futures_datasets\1wk\ZN=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ZS=F.csv -> ./v1_no_volume\futures_datasets\1wk\ZS=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ZT=F.csv -> ./v1_no_volume\futures_datasets\1wk\ZT=F_1wk.csv
# Renaming: ./v1_no_volume\futures_datasets\1wk\ZW=F.csv -> ./v1_no_volume\futures_datasets\1wk\ZW=F_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301090.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301090.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301095.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301095.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301153.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301153.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301155.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301155.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301165.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301165.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301171.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301171.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301175.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301175.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301177.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301177.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301180.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301180.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301200.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301200.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301205.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301205.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301207.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301207.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301216.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301216.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301217.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301217.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301219.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301219.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301238.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301238.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301239.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301239.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301246.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301246.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301262.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301262.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301267.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301267.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301268.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301268.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301286.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301286.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301291.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301291.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301293.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301293.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301301.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301301.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301308.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301308.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301316.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301316.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301325.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301325.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301327.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301327.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301358.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301358.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301363.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301363.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301367.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301367.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301376.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301376.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\301381.SZ.csv -> ./v1_no_volume\stock_datasets\csi500\1d\301381.SZ_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600006.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600006.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600007.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600007.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600012.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600012.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600017.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600017.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600037.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600037.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600055.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600055.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600057.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600057.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600058.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600058.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600059.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600059.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600063.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600063.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600064.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600064.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600072.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600072.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600073.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600073.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600075.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600075.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600098.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600098.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600100.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600100.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600110.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600110.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600116.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600116.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600120.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600120.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600123.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600123.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600125.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600125.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600138.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600138.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600151.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600151.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600158.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600158.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600163.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600163.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600169.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600169.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600172.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600172.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600179.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600179.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600185.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600185.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600195.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600195.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600197.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600197.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600201.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600201.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600206.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600206.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600210.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600210.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600211.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600211.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600216.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600216.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600217.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600217.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600223.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600223.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600225.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600225.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600246.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600246.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600248.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600248.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600252.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600252.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600259.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600259.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600266.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600266.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600267.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600267.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600273.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600273.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600284.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600284.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600285.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600285.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600295.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600295.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600305.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600305.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600312.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600312.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600313.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600313.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600320.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600320.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600323.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600323.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600328.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600328.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600330.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600330.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600331.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600331.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600335.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600335.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600338.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600338.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600340.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600340.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600360.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600360.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600361.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600361.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600363.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600363.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600366.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600366.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600389.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600389.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600391.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600391.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600395.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600395.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600400.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600400.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600403.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600403.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600409.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600409.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600420.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600420.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600422.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600422.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600428.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600428.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600446.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600446.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600449.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600449.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600452.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600452.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600456.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600456.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600458.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600458.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600459.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600459.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600475.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600475.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600477.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600477.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600478.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600478.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600480.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600480.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600483.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600483.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600490.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600490.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600491.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600491.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600496.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600496.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600502.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600502.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600507.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600507.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600508.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600508.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600510.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600510.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600531.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600531.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600550.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600550.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600552.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600552.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600556.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600556.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600557.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600557.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600559.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600559.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600562.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600562.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600572.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600572.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600575.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600575.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600577.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600577.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600578.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600578.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600586.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600586.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600587.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600587.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600595.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600595.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600596.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600596.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600601.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600601.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600602.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600602.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600604.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600604.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600610.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600610.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600612.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600612.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600618.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600618.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600621.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600621.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600623.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600623.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600633.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600633.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600635.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600635.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600639.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600639.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600641.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600641.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600643.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600643.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600645.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600645.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600648.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600648.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600649.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600649.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600657.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600657.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600662.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600662.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600667.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600667.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600675.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600675.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600682.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600682.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600685.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600685.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600688.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600688.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600691.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600691.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600696.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600696.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600710.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600710.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600711.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600711.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600717.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600717.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600718.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600718.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600720.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600720.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600728.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600728.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600729.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600729.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600740.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600740.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600750.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600750.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600751.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600751.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600761.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600761.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600770.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600770.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600771.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600771.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600773.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600773.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600775.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600775.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600776.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600776.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600777.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600777.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600780.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600780.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600782.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600782.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600783.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600783.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600787.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600787.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600797.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600797.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600810.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600810.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600811.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600811.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600812.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600812.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600821.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600821.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600835.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600835.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600850.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600850.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600861.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600861.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600864.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600864.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600869.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600869.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600872.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600872.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600874.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600874.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600876.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600876.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600877.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600877.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600882.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600882.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600888.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600888.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600903.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600903.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600908.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600908.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600916.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600916.SS_1d.csv
# Renaming: ./v1_no_volume\stock_datasets\csi500\1d\600929.SS.csv -> ./v1_no_volume\stock_datasets\csi500\1d\600929.SS_1d.csv
# ...
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NKE.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NKE_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NOC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NOC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NOW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NOW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NRG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NRG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NSC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NSC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NTAP.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NTAP_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NTRS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NTRS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NUE.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NUE_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NVR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NVR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NWS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NWS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\NWSA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\NWSA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\O.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\O_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\OKE.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\OKE_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\OMC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\OMC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ORCL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ORCL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\OTIS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\OTIS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\OXY.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\OXY_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PARA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PARA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PAYC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PAYC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PCG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PCG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PEG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PEG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PFE.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PFE_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PFG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PFG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PGR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PGR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PH.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PH_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PHM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PHM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PKG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PKG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PLD.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PLD_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PNC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PNC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PNR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PNR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PNW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PNW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PODD.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PODD_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\POOL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\POOL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PPG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PPG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PPL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PPL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PRU.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PRU_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PSA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PSA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PSX.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PSX_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PTC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PTC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\PWR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\PWR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RCL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RCL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\REG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\REG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RF.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RF_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RJF.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RJF_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RMD.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RMD_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ROK.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ROK_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ROL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ROL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RSG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RSG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RTX.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RTX_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\RVTY.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\RVTY_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SBAC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SBAC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SCHW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SCHW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SHW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SHW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SJM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SJM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SLB.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SLB_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SMCI.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SMCI_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SNA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SNA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SO.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SO_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SOLV.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SOLV_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SPG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SPG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SPGI.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SPGI_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SRE.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SRE_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\STE.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\STE_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\STLD.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\STLD_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\STT.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\STT_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\STX.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\STX_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\STZ.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\STZ_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SWK.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SWK_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SWKS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SWKS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SYF.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SYF_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SYK.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SYK_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\SYY.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\SYY_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\T.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\T_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TAP.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TAP_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TDG.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TDG_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TDY.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TDY_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TECH.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TECH_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TEL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TEL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TER.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TER_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TFC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TFC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TGT.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TGT_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TJX.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TJX_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TKO.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TKO_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TMO.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TMO_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TPL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TPL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TPR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TPR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TRGP.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TRGP_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TRMB.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TRMB_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TROW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TROW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TRV.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TRV_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TSCO.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TSCO_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TSN.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TSN_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TT.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TT_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TXT.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TXT_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\TYL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\TYL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UAL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UAL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UBER.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UBER_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UDR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UDR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UHS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UHS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ULTA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ULTA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UNH.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UNH_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UNP.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UNP_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\UPS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\UPS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\URI.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\URI_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\USB.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\USB_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\V.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\V_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VICI.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VICI_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VLO.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VLO_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VLTO.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VLTO_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VMC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VMC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VRSN.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VRSN_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VST.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VST_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VTR.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VTR_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VTRS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VTRS_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\VZ.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\VZ_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WAB.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WAB_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WAT.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WAT_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WBA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WBA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WDC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WDC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WEC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WEC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WELL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WELL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WFC.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WFC_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WMB.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WMB_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WMT.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WMT_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WRB.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WRB_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WSM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WSM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WST.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WST_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WTW.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WTW_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WY.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WY_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\WYNN.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\WYNN_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\XOM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\XOM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\XYL.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\XYL_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\YUM.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\YUM_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ZBH.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ZBH_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ZBRA.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ZBRA_1wk.csv
# Renaming: ./v1_no_volume\stock_datasets\sp500\1wk\ZTS.csv -> ./v1_no_volume\stock_datasets\sp500\1wk\ZTS_1wk.csv

# %%
print("done")
# Out:
# done
